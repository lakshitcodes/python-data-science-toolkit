# %%
import numpy as np
import pandas as pd
from numpy.random import randn
# %matplotlib inline

# Create dataframe
my_df = pd.DataFrame(randn(500,4),columns=['Mon','Tues','Wed','Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    1.534412 -1.182112 -1.251898  0.254185
# 1   -0.870195 -1.308827  0.942005  1.533005
# 2    2.018200  0.858632  0.460253  1.167352
# 3    0.554016 -1.161321 -0.171145 -1.514901
# 4   -0.096878 -1.409896 -0.866647  0.530593
# ..        ...       ...       ...       ...
# 495  0.271701  1.049927 -0.488058  1.138043
# 496  1.789640  0.530566 -1.922926  0.055822
# 497 -1.826185 -0.372829  1.268549  1.402504
# 498 -1.390004 -1.929945 -0.016737  0.674544
# 499 -0.326764  1.577436  0.853915  0.068907
#
# [500 rows x 4 columns]

# %%
# Density and Kernel density estimation plots with scipy
my_df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# KDE second way to learn shift tab
my_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Density Plot
my_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# Other way, title and grid work the same as others
# can use alpha , lw (line width)
