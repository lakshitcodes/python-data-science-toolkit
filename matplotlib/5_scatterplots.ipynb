# %%
import numpy as np
import pandas as pd
from numpy.random import randn
# %matplotlib inline

# Create dataframe
my_df = pd.DataFrame(randn(500,4),columns=['Mon','Tues','Wed','Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.141296  1.003702 -1.683012 -0.046041
# 1   -0.769680  0.239476  1.751092  0.363242
# 2   -0.761076  0.078894  0.863131 -1.429477
# 3    0.745307 -0.078501  0.156506  0.870875
# 4   -1.760853 -0.765997 -0.277274 -0.573976
# ..        ...       ...       ...       ...
# 495 -0.241973 -1.844550 -0.480014 -0.828516
# 496  0.561995  1.903139 -0.777868 -1.482409
# 497  0.108278 -1.355675  0.092138  0.130240
# 498 -0.252479 -0.628382 -1.943140  1.870920
# 499  0.374420  1.954892 -0.951626  0.609923
#
# [500 rows x 4 columns]

# %%
# Scatter plot
my_df.plot(kind='scatter',x='Mon',y='Tues',c='Wed')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Colors : https://matplotlib.org/stable/users/explain/colors/colormaps.html
my_df.plot(kind='scatter',x='Mon',y='Tues',c='Wed',cmap='magma')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By size
my_df.plot(kind='scatter',x='Mon',y='Tues',s=my_df['Wed']*100)
# Out:
# C:\Users\jainl\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By size easier to read with alpha
my_df.plot(kind='scatter',x='Mon',y='Tues',s=my_df['Wed']*100,alpha=0.4)
# Out:
# C:\Users\jainl\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Add title
my_df.plot(kind='scatter',x='Mon',y='Tues',s=my_df['Wed']*100,alpha=0.4,title="My Awesome Scatter plot")
# Out:
# C:\Users\jainl\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: title={'center': 'My Awesome Scatter plot'}, xlabel='Mon', ylabel='Tues'>
