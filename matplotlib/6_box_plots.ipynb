# %%
import numpy as np
import pandas as pd
from numpy.random import randn
# %matplotlib inline

# Create dataframe
my_df = pd.DataFrame(randn(500,4),columns=['Mon','Tues','Wed','Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    1.289438 -0.845017  1.092074 -2.621654
# 1    1.588302  1.302099 -1.528230 -0.384332
# 2    0.369620 -0.721458  0.832434  0.089154
# 3   -1.064753  0.892519 -1.474797 -1.656005
# 4   -0.716608  0.485695 -1.035138 -0.275985
# ..        ...       ...       ...       ...
# 495  0.068050 -0.529983  1.044582 -0.855173
# 496  0.094662 -0.409495  0.324083 -1.565045
# 497 -0.246261  0.093462 -0.515082 -0.453103
# 498  0.210432  0.726772  1.189758  0.062507
# 499  0.827995  1.549673  0.462533  1.721349
#
# [500 rows x 4 columns]

# %%
# Box plots
my_df.plot(kind='box')
# Out:
# <Axes: >

# %%
# boxplots size
my_df.plot(kind='box',figsize=(10,5))
# Out:
# <Axes: >

# %%
# Boxplots color
my_df.plot(kind='box',cmap='jet')
# Out:
# <Axes: >

# %%
# Legend
my_df.plot(kind='box',legend=True)
# Out:
# <Axes: >

# %%
# Title
my_df.plot(kind='box',title="My box plot")
# Out:
# <Axes: title={'center': 'My box plot'}>

# %%
# Other way
my_df.plot.box()
# Out:
# <Axes: >

# %%
# Add grid
my_df.plot(kind='box',title="My box plot",grid=True)
# Out:
# <Axes: title={'center': 'My box plot'}>
