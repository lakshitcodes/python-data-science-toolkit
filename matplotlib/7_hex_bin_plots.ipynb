# %%
import numpy as np
import pandas as pd
from numpy.random import randn
# %matplotlib inline

# Create dataframe
my_df = pd.DataFrame(randn(500,4),columns=['Mon','Tues','Wed','Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.657668 -0.630491  0.900373  0.208471
# 1    0.172212  0.583429  1.291241 -1.054656
# 2   -0.168822  0.317592 -0.506702  1.087545
# 3    1.416113 -0.549068 -1.619496  0.536349
# 4    0.908957 -1.649548 -0.513281 -1.063312
# ..        ...       ...       ...       ...
# 495  0.066319 -0.599886 -1.194683 -0.673618
# 496 -0.484427 -1.156299 -0.004150  0.079491
# 497 -1.189494 -0.989750  0.873323  1.578408
# 498 -2.079566 -0.672374 -0.685072 -1.447356
# 499 -0.024250  1.695370  0.402856 -0.377016
#
# [500 rows x 4 columns]

# %%
# Hexplots
my_df.plot(kind='hexbin',x='Mon',y='Tues')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots grid size
# Bigger grid size -> Smaller hexagon size
my_df.plot(kind='hexbin',x='Mon',y='Tues',gridsize=25)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots color
my_df.plot(kind='hexbin',x='Mon',y='Tues',gridsize=10,cmap='magma')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Other method
my_df.plot.hexbin(x='Mon',y='Tues',gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title
my_df.plot.hexbin(x='Mon',y='Tues',gridsize=10,title="my hexbin plot")
# Out:
# <Axes: title={'center': 'my hexbin plot'}, xlabel='Mon', ylabel='Tues'>

# %%
# Grid
my_df.plot.hexbin(x='Mon',y='Tues',gridsize=10,grid=True)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>
